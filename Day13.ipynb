# %% [markdown]
# Question:
# Prepare a case study for the given Dataset implement the following steps:
# Steps:
# 1. Import different required library
# 2. Check the version of Library
# 3. Go for different observation like Info, description
# 4. Check null Values
# 5. Check duplicate values
# 6. Filter for different condition - come up with insights from the dataset , basic plot , distribution plots
# 7. Use a histogram to plot different columns

# %%
import pandas as pd

# %%
movies=pd.read_csv(r"C:\Users\pavan kumar\Documents\pandasdata\ml-latest-small\movies.csv")

# %%
ratings=pd.read_csv(r"C:\Users\pavan kumar\Documents\pandasdata\ml-latest-small\ratings.csv")
tags=pd.read_csv(r"C:\Users\pavan kumar\Documents\pandasdata\ml-latest-small\tags.csv")

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
tags
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
movies.describe
# Out:
# <bound method NDFrame.describe of       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# ...

# %%
movies.describe()
# Out:
#              movieId
# count    9742.000000
# mean    42200.353623
# std     52160.494854
# min         1.000000
# 25%      3248.250000
# 50%      7300.000000
# 75%     76232.000000
# max    193609.000000

# %%
movies.isna()
# Out:
#       movieId  title  genres
# 0       False  False   False
# 1       False  False   False
# 2       False  False   False
# 3       False  False   False
# 4       False  False   False
# ...       ...    ...     ...
# 9737    False  False   False
# 9738    False  False   False
# 9739    False  False   False
# 9740    False  False   False
# 9741    False  False   False
#
# [9742 rows x 3 columns]

# %%
tags.isna()
# Out:
#       userId  movieId    tag  timestamp
# 0      False    False  False      False
# 1      False    False  False      False
# 2      False    False  False      False
# 3      False    False  False      False
# 4      False    False  False      False
# ...      ...      ...    ...        ...
# 3678   False    False  False      False
# 3679   False    False  False      False
# 3680   False    False  False      False
# 3681   False    False  False      False
# 3682   False    False  False      False
#
# [3683 rows x 4 columns]

# %%
df=movies.merge(tags,on='movieId',how='inner')
df
# Out:
#       movieId                           title  \
# 0           1                Toy Story (1995)
# 1           1                Toy Story (1995)
# 2           1                Toy Story (1995)
# 3           2                  Jumanji (1995)
# 4           2                  Jumanji (1995)
# ...       ...                             ...
# 3678   187595  Solo: A Star Wars Story (2018)
# 3679   193565       Gintama: The Movie (2010)
# 3680   193565       Gintama: The Movie (2010)
# 3681   193565       Gintama: The Movie (2010)
# 3682   193565       Gintama: The Movie (2010)
#
#                                            genres  userId               tag  \
# 0     Adventure|Animation|Children|Comedy|Fantasy     336             pixar
# 1     Adventure|Animation|Children|Comedy|Fantasy     474             pixar
# 2     Adventure|Animation|Children|Comedy|Fantasy     567               fun
# 3                      Adventure|Children|Fantasy      62           fantasy
# ...

# %%
df.isna()
# Out:
#       movieId  title  genres  userId    tag  timestamp
# 0       False  False   False   False  False      False
# 1       False  False   False   False  False      False
# 2       False  False   False   False  False      False
# 3       False  False   False   False  False      False
# 4       False  False   False   False  False      False
# ...       ...    ...     ...     ...    ...        ...
# 3678    False  False   False   False  False      False
# 3679    False  False   False   False  False      False
# 3680    False  False   False   False  False      False
# 3681    False  False   False   False  False      False
# 3682    False  False   False   False  False      False
#
# [3683 rows x 6 columns]

# %%
df.isna().head(10)
# Out:
#    movieId  title  genres  userId    tag  timestamp
# 0    False  False   False   False  False      False
# 1    False  False   False   False  False      False
# 2    False  False   False   False  False      False
# 3    False  False   False   False  False      False
# 4    False  False   False   False  False      False
# 5    False  False   False   False  False      False
# 6    False  False   False   False  False      False
# 7    False  False   False   False  False      False
# 8    False  False   False   False  False      False
# 9    False  False   False   False  False      False

# %%
boolean = not df["title"].is_unique      
boolean = df['title'].duplicated().any()
boolean
# Out:
# True

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
ratings_high= ratings['rating'] > 4
ratings[ratings_high]
# Out:
#         userId  movieId  rating   timestamp
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# 6            1      101     5.0   964980868
# 8            1      151     5.0   964984041
# 9            1      157     5.0   964984100
# ...        ...      ...     ...         ...
# 100821     610   160527     4.5  1479544998
# 100829     610   164179     5.0  1493845631
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
#
# [21762 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
ratings.hist(column='rating',figsize=(5,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002564395EAC0>]],
#       dtype=object)
